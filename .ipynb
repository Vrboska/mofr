# %% [markdown]
# # Testing packages

# %%
import pandas as pd
import numpy as np
import random

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Simple scores

# %%
from mofr import metrics

# %%
df=pd.read_csv(r'c:\Users\T862363F\Projects\DevOps_Repos\PRG_TD_ModellingFramework\data\Model_Eval_Data_For_Andrej.csv')

# %%
df['p_churn']=df['p_alive']*-1+1
df['target_obs']=1
df['random_score']=np.random.randint(1, 1000000, df.shape[0])/1000000
df['semi_random_score']=0.7*df['p_churn']+0.3*np.random.normal(0,1,df.shape[0])
df['month']=df['target_obs'].apply(lambda x: random.choice([202001,202002,202003]))

# %%
len(df)
# Out:
# 7946

# %%
df.head()
# Out:
#    TECCOMPCE  TECSOLDTO   p_alive          CLV  p_alive_  PB_Churn_Flag  CLV_  \
# 0         40     636362  0.994196  2821.981425         0    994196067.0     0
# 1         40     441577  0.613307     0.000000         0    613306736.0     0
# 2         40     422141  0.462324  3340.062341         0    462324357.0     1
# 3         40     706342  0.841013  5023.797898         0    841012858.0     0
# 4         40     718698  0.668060     0.000000         0    668060235.0     0
#
#      ob       omx                          omn  ...  \
# 0  2821  981425.0                           11  ...
# 1     0       1.0  2018-10-01 00:00:00.0000000  ...
# 2  3340   62341.0                            7  ...
# 3  5023  797898.0                           17  ...
# 4     0       1.0  2019-02-06 00:00:00.0000000  ...
#
#                    CreditBlock                        Churn    a    b target  \
# 0  2020-09-29 00:00:00.0000000  2019-10-01 00:00:00.0000000  NaN  0.0      0
# 1                          NaN                          NaN  1.0  NaN      1
# 2  2020-07-01 00:00:00.0000000  2020-02-19 00:00:00.0000000  NaN  0.0      0
# 3  2020-07-17 00:00:00.0000000  2019-10-03 00:00:00.0000000  NaN  0.0      0
# 4  2020-01-10 00:00:00.0000000                          NaN  0.0  NaN      0
#
#    target_obs   p_churn  random_score  semi_random_score   month
# 0           1  0.005804      0.233802          -0.097242  202001
# 1           1  0.386693      0.196697          -0.136254  202002
# 2           1  0.537676      0.049014           0.473350  202003
# 3           1  0.158987      0.696181           0.073900  202003
# 4           1  0.331940      0.344225           0.357221  202001
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Accuracy

# %%
metrics.accuracy_score(df['target'], df['p_churn']>0.5)
# Out:
# 0.7793858545179965

# %%
[metrics.accuracy_score(df['target'], df['p_churn']>(x+1)/1000) for x in range(20)]
# Out:
# [0.31059652655424114,
#  0.40057890762647874,
#  0.46967027435187514,
#  0.5117040020135918,
#  0.5485779008306066,
#  0.5690913667253964,
#  0.591492574880443,
#  0.6063428139944627,
#  0.618801912912157,
#  0.6303800654417316,
#  0.6401963251950668,
#  0.6477472942360937,
#  0.6552982632771206,
#  0.6614648879939592,
#  0.6676315127107979,
#  0.6720362446513969,
#  0.676566826076013,
#  0.6827334507928517,
#  0.6867606342813994,
#  0.6906619682859301]

# %%
#metrics.accuracy_score?

# %% [markdown]
# ### Precision

# %%
metrics.precision_score(df['target'], df['p_churn']>0.5)
# Out:
# 0.5398230088495575

# %%
[metrics.precision_score(df['target'], df['p_churn']>(99-x)/100) for x in range(20)]
# Out:
# [0.6588235294117647,
#  0.6239316239316239,
#  0.625,
#  0.618421052631579,
#  0.6073619631901841,
#  0.6123595505617978,
#  0.6096256684491979,
#  0.6062176165803109,
#  0.6019417475728155,
#  0.591304347826087,
#  0.5887096774193549,
#  0.5889328063241107,
#  0.5923076923076923,
#  0.6,
#  0.5949820788530465,
#  0.5929824561403508,
#  0.5932203389830508,
#  0.5907590759075908,
#  0.6006191950464397,
#  0.600609756097561]

# %%
#metrics.precision_score?

# %% [markdown]
# ### Recall

# %%
metrics.recall_score(df['target'], df['p_churn']>0.5)
# Out:
# 0.20254565578306585

# %%
[metrics.recall_score(df['target'], df['p_churn']>(99-x)/100) for x in range(20)]
# Out:
# [0.03099059214167128,
#  0.040398450470392915,
#  0.04703929164360819,
#  0.05201992252351965,
#  0.05478693967902601,
#  0.06032097399003874,
#  0.0630879911455451,
#  0.06474820143884892,
#  0.06862202545655784,
#  0.0752628666297731,
#  0.08079690094078583,
#  0.08245711123408965,
#  0.08522412838959602,
#  0.0896513558384062,
#  0.09186496956281129,
#  0.09352517985611511,
#  0.09684560044272275,
#  0.09905921416712783,
#  0.10736026563364692,
#  0.10902047592695074]

# %%
#metrics.recall_score?

# %% [markdown]
# ### F1 score

# %%
metrics.f1_score(df['target'], df['p_churn']>0.5)
# Out:
# 0.2945674044265594

# %%
[metrics.f1_score(df['target'], df['p_churn']>(x+1)/1000) for x in range(20)]
# Out:
# [0.39749230092388915,
#  0.4314193625402889,
#  0.46057347670250887,
#  0.48072805139186287,
#  0.5000696864111499,
#  0.5107173478136611,
#  0.5233480176211454,
#  0.5313155528918191,
#  0.5383325712543819,
#  0.545144804088586,
#  0.5509659180147636,
#  0.5550786838340487,
#  0.5590082112381259,
#  0.5628859278518037,
#  0.5664094565752751,
#  0.5691137566137566,
#  0.5709515859766277,
#  0.5755177639333221,
#  0.5776344815883251,
#  0.5796853625170998]

# %%
#metrics.f1_score?

# %% [markdown]
# ### Confusion matrix

# %%
metrics.confusion_matrix(df['target'], df['p_churn']>0.5)
# Out:
# array([[5827,  312],
#        [1441,  366]], dtype=int64)

# %% [markdown]
# ### ROC AUC

# %%
metrics.roc_auc_score(df['target'], df['p_churn'])
# Out:
# 0.8560895967276451

# %%
#metrics.roc_auc_score?

# %% [markdown]
# ### GINI

# %%
metrics.gini(df['target'], df['p_churn'])
# Out:
# 0.7121791934552901

# %%
metrics.gini(df['target'], df['p_churn'], average='samples')
# Out:
# 0.7121791934552901

# %%
#metrics.gini?

# %% [markdown]
# ### Lift

# %%
metrics.lift(df['target'], df['p_churn'])
# Out:
# 2.306531204644412

# %%
metrics.liftN(df['target'], df['p_churn'], 0.05)
# Out:
# 2.519081294685937

# %%
[metrics.liftN(df['target'], df['p_churn'],(x+1)/10) for x in range(1,10)]
# Out:
# [2.564655037052907,
#  2.418539014941893,
#  2.1267203306629034,
#  1.8638627559490868,
#  1.6290557813709337,
#  1.4191355404598403,
#  1.2480818075848659,
#  1.111484123653658,
#  1]

# %% [markdown]
# ### KS score

# %%
metrics.ks_score(df['target'], df['p_churn'])
# Out:
# 0.588206908879903

# %%
#metrics.ks_score?

# %% [markdown]
# ## Curves and others

# %% [markdown]
# ### ROC curve

# %%
metrics.roc_curve(df['target'], df['p_churn'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99788239, 0.99837107,
#         1.        ]),
#  array([0.00000000e+00, 5.53403431e-04, 7.74764804e-03, ...,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00]),
#  array([2.0000000e+00, 1.0000000e+00, 9.9999814e-01, ..., 1.7253500e-04,
#         1.7186300e-04, 1.5661200e-04]))

# %%
from matplotlib import pyplot as plt
_fpr, _tpr, _ = metrics.roc_curve(df['target'], df['p_churn'])

# plot the roc curve for the model
plt.plot(_fpr, _tpr, linestyle='-', color='red', label='Model 1')

# axis labels
plt.title('ROC curve')
plt.xlim(-0.01,1.01)
plt.ylim(-0.01,1.03)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()

# %%
#metrics.roc_curve?

# %% [markdown]
# ### Lift curve

# %%
[metrics.liftN(df['target'], df['p_churn'], x/10) for x in range (1,11)]
# Out:
# [2.306531204644412,
#  2.564655037052907,
#  2.418539014941893,
#  2.1267203306629034,
#  1.8638627559490868,
#  1.6290557813709337,
#  1.4191355404598403,
#  1.2480818075848659,
#  1.111484123653658,
#  1]

# %%
from matplotlib import pyplot as plt
x= [(x/10) for x in range (1,11)]
lift_curve = [metrics.liftN(df['target'], df['p_churn'], x/10) for x in range (1,11)]
plt.plot(x, lift_curve, linestyle='-', color='red', label='Model 1')
# axis labels
plt.title('Lift curve')
#plt.xlim(-0.01,1.01)
#plt.ylim(-0.01,1.03)
#plt.xlabel('False Positive Rate')
#plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()

# %% [markdown]
# ### Precision-Recall curve

# %%
metrics.precision_recall_curve(df['target'], df['p_churn'])
# Out:
# (array([0.27778632, 0.27767528, 0.27771798, ..., 1.        , 1.        ,
#         1.        ]),
#  array([1.00000000e+00, 9.99446597e-01, 9.99446597e-01, ...,
#         1.10680686e-03, 5.53403431e-04, 0.00000000e+00]),
#  array([0.00209515, 0.00209674, 0.00209705, ..., 1.        , 1.        ,
#         1.        ]))

# %%
from matplotlib import pyplot as plt


f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))
lines.append(l)
labels.append('iso-f1 curves')

lr_precision, lr_recall, _ = metrics.precision_recall_curve(df['target'], df['p_churn'])
# plot the precision-recall curves
no_skill = len(df['target'][df['target']==1]) / len(df['target'])
plt.plot([0, 1], [no_skill, no_skill], linestyle='--')
l,=plt.plot(lr_recall, lr_precision,linestyle='-', color='red', label='Model 1')
lines.append(l)
labels.append('Model 1')
# axis labels
plt.title('Precision-Recall curve with iso-f1 curves')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
# show the legend
plt.legend(lines,labels)
# show the plot
plt.show()

# %% [markdown]
# # Basic Evaluators

# %% [markdown]
# ## Lift Curve Evaluator

# %%
from mofr.basic_evaluators.LiftCurve import LiftCurveEvaluator

lce=LiftCurveEvaluator()
#help(lce)

# %%
lce.d(df).t([('target','target_obs')]).s(['p_churn', 'semi_random_score','random_score'])

# %%
lce.get_graph()

# %% [markdown]
# ## ROC Curve Evaluator

# %%
from mofr.basic_evaluators.ROCCurve import ROCCurveEvaluator

rce=ROCCurveEvaluator()
#help(rce)

# %%
rce.d(df).t([('target','target_obs')]).s(['p_churn', 'semi_random_score','random_score'])

# %%
rce.get_graph()

# %% [markdown]
# ## PR Curve Evaluator

# %%
from mofr.basic_evaluators.PRCurve import PRCurveEvaluator

prce=PRCurveEvaluator()
#help(prce)

# %%
prce.d(df).t([('target','target_obs')]).s(['p_churn', 'semi_random_score','random_score'])

# %%
prce.get_graph()

# %%
prce.get_graph(isocurves='on')

# %% [markdown]
# ## Gini in Time Evaluator

# %%
from mofr.basic_evaluators.GiniInTime import GiniInTimeEvaluator

gite=GiniInTimeEvaluator()
#help(gite)

# %%
gite.d(df).t([('target','target_obs')]).s(['p_churn', 'semi_random_score','random_score']).tc('month')

# %%
gite.get_graph()

# %%
gite.get_table()
gite.table
# Out:
# <style  type="text/css" >
# </style><table id="T_80c86b7a_b429_11ec_bf98_5c879c826b52" style='display:inline'><caption>GINI on target "target"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >p_churn</th>        <th class="col_heading level0 col1" >semi_random_score</th>        <th class="col_heading level0 col2" >random_score</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80c86b7a_b429_11ec_bf98_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row0_col0" class="data row0 col0" >0.711848</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row0_col1" class="data row0 col1" >0.329085</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row0_col2" class="data row0 col2" >-0.000980</td>
#             </tr>
#             <tr>
#                         <th id="T_80c86b7a_b429_11ec_bf98_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row1_col0" class="data row1 col0" >0.693527</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row1_col1" class="data row1 col1" >0.289003</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row1_col2" class="data row1 col2" >0.007518</td>
#             </tr>
#             <tr>
#                         <th id="T_80c86b7a_b429_11ec_bf98_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row2_col0" class="data row2 col0" >0.730559</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row2_col1" class="data row2 col1" >0.307675</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row2_col2" class="data row2 col2" >0.015433</td>
#             </tr>
#             <tr>
#                         <th id="T_80c86b7a_b429_11ec_bf98_5c879c826b52level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row3_col0" class="data row3 col0" >0.712179</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row3_col1" class="data row3 col1" >0.308631</td>
#                         <td id="T_80c86b7a_b429_11ec_bf98_5c879c826b52row3_col2" class="data row3 col2" >0.007146</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Lift in Time Evaluator

# %%
from mofr.basic_evaluators.LiftInTime import LiftInTimeEvaluator

lite=LiftInTimeEvaluator()
#help(lite)

# %%
lite.d(df).t([('target','target_obs')]).s(['p_churn', 'semi_random_score','random_score']).tc('month')

# %%
lite.get_graph()

# %%
lite.get_table()
lite.table
# Out:
# <style  type="text/css" >
# </style><table id="T_8164ab62_b429_11ec_bac9_5c879c826b52" style='display:inline'><caption>Lift on target "target"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >p_churn</th>        <th class="col_heading level0 col1" >semi_random_score</th>        <th class="col_heading level0 col2" >random_score</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8164ab62_b429_11ec_bac9_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row0_col0" class="data row0 col0" >2.286500</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row0_col1" class="data row0 col1" >1.883000</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row0_col2" class="data row0 col2" >1.025562</td>
#             </tr>
#             <tr>
#                         <th id="T_8164ab62_b429_11ec_bac9_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row1_col0" class="data row1 col0" >2.249819</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row1_col1" class="data row1 col1" >1.930815</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row1_col2" class="data row1 col2" >0.856274</td>
#             </tr>
#             <tr>
#                         <th id="T_8164ab62_b429_11ec_bac9_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row2_col0" class="data row2 col0" >2.382078</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row2_col1" class="data row2 col1" >1.968468</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row2_col2" class="data row2 col2" >1.048774</td>
#             </tr>
#             <tr>
#                         <th id="T_8164ab62_b429_11ec_bac9_5c879c826b52level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row3_col0" class="data row3 col0" >2.306531</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row3_col1" class="data row3 col1" >1.913812</td>
#                         <td id="T_8164ab62_b429_11ec_bac9_5c879c826b52row3_col2" class="data row3 col2" >0.990094</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## KS in Time Evaluator

# %%
from mofr.basic_evaluators.KSInTime import KSInTimeEvaluator

kite=KSInTimeEvaluator()
#help(kite)

# %%
kite.d(df).t([('target','target_obs')]).s(['p_churn', 'semi_random_score','random_score']).tc('month')

# %%
kite.get_graph()

# %%
kite.get_table()
kite.table
# Out:
# <style  type="text/css" >
# </style><table id="T_82679c80_b429_11ec_ab08_5c879c826b52" style='display:inline'><caption>KS on target "target"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >p_churn</th>        <th class="col_heading level0 col1" >semi_random_score</th>        <th class="col_heading level0 col2" >random_score</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82679c80_b429_11ec_ab08_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row0_col0" class="data row0 col0" >0.583087</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row0_col1" class="data row0 col1" >0.257922</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row0_col2" class="data row0 col2" >0.036399</td>
#             </tr>
#             <tr>
#                         <th id="T_82679c80_b429_11ec_ab08_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row1_col0" class="data row1 col0" >0.578389</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row1_col1" class="data row1 col1" >0.224190</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row1_col2" class="data row1 col2" >0.034281</td>
#             </tr>
#             <tr>
#                         <th id="T_82679c80_b429_11ec_ab08_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row2_col0" class="data row2 col0" >0.607898</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row2_col1" class="data row2 col1" >0.245230</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row2_col2" class="data row2 col2" >0.038525</td>
#             </tr>
#             <tr>
#                         <th id="T_82679c80_b429_11ec_ab08_5c879c826b52level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row3_col0" class="data row3 col0" >0.588207</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row3_col1" class="data row3 col1" >0.232301</td>
#                         <td id="T_82679c80_b429_11ec_ab08_5c879c826b52row3_col2" class="data row3 col2" >0.021582</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## StabilityInTimeCategorical Evaluator

# %%
df['categorical_predictor']=df['target_obs'].apply(lambda x: random.choice(['A','B','C', 'D', 'F', 'G', 'H']))

# %%
from mofr.basic_evaluators.StabilityInTimeCategorical import StabilityInTimeCategoricalEvaluator

sitcae=StabilityInTimeCategoricalEvaluator()
#help(sitcae)

# %%
sitcae.d(df).pc('categorical_predictor').tc('month')

# %%
sitcae.get_graph()

# %%
sitcae.get_table()
sitcae.table
# Out:
# <style  type="text/css" >
# </style><table id="T_83095ad4_b429_11ec_8b18_5c879c826b52" style='display:inline'><caption>Distribution of predictor "categorical_predictor" in time</caption><thead>    <tr>        <th class="index_name level0" >categorical_predictor</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >F</th>        <th class="col_heading level0 col5" >G</th>        <th class="col_heading level0 col6" >H</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83095ad4_b429_11ec_8b18_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col0" class="data row0 col0" >0.146858</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col1" class="data row0 col1" >0.151779</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col2" class="data row0 col2" >0.133611</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col3" class="data row0 col3" >0.144966</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col4" class="data row0 col4" >0.140424</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col5" class="data row0 col5" >0.144209</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row0_col6" class="data row0 col6" >0.138153</td>
#             </tr>
#             <tr>
#                         <th id="T_83095ad4_b429_11ec_8b18_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col0" class="data row1 col0" >0.151562</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col1" class="data row1 col1" >0.141149</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col2" class="data row1 col2" >0.155804</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col3" class="data row1 col3" >0.134593</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col4" class="data row1 col4" >0.140378</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col5" class="data row1 col5" >0.136907</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row1_col6" class="data row1 col6" >0.139607</td>
#             </tr>
#             <tr>
#                         <th id="T_83095ad4_b429_11ec_8b18_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col0" class="data row2 col0" >0.139063</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col1" class="data row2 col1" >0.135743</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col2" class="data row2 col2" >0.138325</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col3" class="data row2 col3" >0.142752</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col4" class="data row2 col4" >0.149391</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col5" class="data row2 col5" >0.154556</td>
#                         <td id="T_83095ad4_b429_11ec_8b18_5c879c826b52row2_col6" class="data row2 col6" >0.140170</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## StabilityInTimeContinuous Evaluator

# %%
from mofr.basic_evaluators.StabilityInTimeContinuous import StabilityInTimeContinuousEvaluator

sitcoe=StabilityInTimeContinuousEvaluator()
#help(sitcoe)

# %%
sitcoe.d(df).pc('p_churn').tc('month')

# %%
sitcoe.get_graph()

# %%
sitcoe.get_table()
sitcoe.table
# Out:
# <style  type="text/css" >
# </style><table id="T_83a45380_b429_11ec_830a_5c879c826b52" style='display:inline'><caption>Distribution of predictor "p_churn" in time</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >percentile_10</th>        <th class="col_heading level0 col1" >percentile_25</th>        <th class="col_heading level0 col2" >percentile_50</th>        <th class="col_heading level0 col3" >percentile_75</th>        <th class="col_heading level0 col4" >percentile_90</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a45380_b429_11ec_830a_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row0_col0" class="data row0 col0" >0.001167</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row0_col1" class="data row0 col1" >0.003060</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row0_col2" class="data row0 col2" >0.019767</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row0_col3" class="data row0 col3" >0.240226</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row0_col4" class="data row0 col4" >0.411633</td>
#             </tr>
#             <tr>
#                         <th id="T_83a45380_b429_11ec_830a_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row1_col0" class="data row1 col0" >0.001233</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row1_col1" class="data row1 col1" >0.003383</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row1_col2" class="data row1 col2" >0.026382</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row1_col3" class="data row1 col3" >0.265371</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row1_col4" class="data row1 col4" >0.401990</td>
#             </tr>
#             <tr>
#                         <th id="T_83a45380_b429_11ec_830a_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row2_col0" class="data row2 col0" >0.001072</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row2_col1" class="data row2 col1" >0.002977</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row2_col2" class="data row2 col2" >0.020401</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row2_col3" class="data row2 col3" >0.242105</td>
#                         <td id="T_83a45380_b429_11ec_830a_5c879c826b52row2_col4" class="data row2 col4" >0.386333</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## HistogramCategorical Evaluator

# %%
df['categorical_predictor']=df['target_obs'].apply(lambda x: random.choice(['A','B','C', 'D', 'F', 'G', 'H']))

# %%
from mofr.basic_evaluators.HistogramCategorical import HistogramCategoricalEvaluator

hcae=HistogramCategoricalEvaluator()
#help(hcae)

# %%
hcae.d(df).pc('categorical_predictor')

# %%
hcae.get_graph()

# %%
hcae.get_graph(plot=False)

# %%
hcae.get_table()
hcae.table
# Out:
# <style  type="text/css" >
# </style><table id="T_8457148c_b429_11ec_85f8_5c879c826b52" style='display:inline'><caption>Distribution of predictor "categorical_predictor"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >categorical_predictor %</th>        <th class="col_heading level0 col1" >categorical_predictor</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row0" class="row_heading level0 row0" >A</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row0_col0" class="data row0 col0" >0.149761</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row0_col1" class="data row0 col1" >1190</td>
#             </tr>
#             <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row1" class="row_heading level0 row1" >B</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row1_col0" class="data row1 col0" >0.145482</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row1_col1" class="data row1 col1" >1156</td>
#             </tr>
#             <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row2" class="row_heading level0 row2" >G</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row2_col0" class="data row2 col0" >0.145230</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row2_col1" class="data row2 col1" >1154</td>
#             </tr>
#             <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row3" class="row_heading level0 row3" >F</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row3_col0" class="data row3 col0" >0.142210</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row3_col1" class="data row3 col1" >1130</td>
#             </tr>
#             <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row4" class="row_heading level0 row4" >D</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row4_col0" class="data row4 col0" >0.140448</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row4_col1" class="data row4 col1" >1116</td>
#             </tr>
#             <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row5" class="row_heading level0 row5" >H</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row5_col0" class="data row5 col0" >0.140070</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row5_col1" class="data row5 col1" >1113</td>
#             </tr>
#             <tr>
#                         <th id="T_8457148c_b429_11ec_85f8_5c879c826b52level0_row6" class="row_heading level0 row6" >C</th>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row6_col0" class="data row6 col0" >0.136798</td>
#                         <td id="T_8457148c_b429_11ec_85f8_5c879c826b52row6_col1" class="data row6 col1" >1087</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## HistogramContinuous Evaluator

# %%
from mofr.basic_evaluators.HistogramContinuous import HistogramContinuousEvaluator

hcoe=HistogramContinuousEvaluator()
#help(hcoe)

# %%
hcoe.d(df).pc('p_churn')

# %%
hcoe.get_graph()

# %%
hcoe.graph

# %%
hcoe.get_table()
hcoe.table
# Out:
# <style  type="text/css" >
# </style><table id="T_85191988_b429_11ec_aa7d_5c879c826b52" style='display:inline'><caption>Percentiles of predictor "p_churn"</caption><thead>    <tr>        <th class="index_name level0" ></th>        <th class="col_heading level0 col0" >p_churn</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85191988_b429_11ec_aa7d_5c879c826b52level0_row0" class="row_heading level0 row0" >percentile_10</th>
#                         <td id="T_85191988_b429_11ec_aa7d_5c879c826b52row0_col0" class="data row0 col0" >0.001139</td>
#             </tr>
#             <tr>
#                         <th id="T_85191988_b429_11ec_aa7d_5c879c826b52level0_row1" class="row_heading level0 row1" >percentile_25</th>
#                         <td id="T_85191988_b429_11ec_aa7d_5c879c826b52row1_col0" class="data row1 col0" >0.003166</td>
#             </tr>
#             <tr>
#                         <th id="T_85191988_b429_11ec_aa7d_5c879c826b52level0_row2" class="row_heading level0 row2" >percentile_50</th>
#                         <td id="T_85191988_b429_11ec_aa7d_5c879c826b52row2_col0" class="data row2 col0" >0.021627</td>
#             </tr>
#             <tr>
#                         <th id="T_85191988_b429_11ec_aa7d_5c879c826b52level0_row3" class="row_heading level0 row3" >percentile_75</th>
#                         <td id="T_85191988_b429_11ec_aa7d_5c879c826b52row3_col0" class="data row3 col0" >0.247600</td>
#             </tr>
#             <tr>
#                         <th id="T_85191988_b429_11ec_aa7d_5c879c826b52level0_row4" class="row_heading level0 row4" >percentile_90</th>
#                         <td id="T_85191988_b429_11ec_aa7d_5c879c826b52row4_col0" class="data row4 col0" >0.401849</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## TargetAssociationCategorical Evaluator

# %%
df['categorical_predictor']=df['target_obs'].apply(lambda x: random.choice(['A','B','C', 'D', 'F', 'G', 'H']))

# %%
from mofr.basic_evaluators.TargetAssociationCategorical import TargetAssociationCategoricalEvaluator

tacae=TargetAssociationCategoricalEvaluator()
#help(tacae)

# %%
tacae.d(df).t([('target', 'target_obs')]).pc('categorical_predictor').tc('month')

# %%
tacae.get_graph()

# %%
tacae.get_table()
tacae.table
# Out:
# <style  type="text/css" >
# </style><table id="T_85be6ebe_b429_11ec_b03c_5c879c826b52" style='display:inline'><caption>Target association (default rate) of predictor "categorical_predictor" in time</caption><thead>    <tr>        <th class="index_name level0" >categorical_predictor</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >F</th>        <th class="col_heading level0 col5" >G</th>        <th class="col_heading level0 col6" >H</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85be6ebe_b429_11ec_b03c_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col0" class="data row0 col0" >0.119730</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col1" class="data row0 col1" >0.129848</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col2" class="data row0 col2" >0.134907</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col3" class="data row0 col3" >0.146712</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col4" class="data row0 col4" >0.155143</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col5" class="data row0 col5" >0.155143</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row0_col6" class="data row0 col6" >0.158516</td>
#             </tr>
#             <tr>
#                         <th id="T_85be6ebe_b429_11ec_b03c_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col0" class="data row1 col0" >0.148148</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col1" class="data row1 col1" >0.141414</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col2" class="data row1 col2" >0.149832</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col3" class="data row1 col3" >0.148148</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col4" class="data row1 col4" >0.129630</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col5" class="data row1 col5" >0.143098</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row1_col6" class="data row1 col6" >0.139731</td>
#             </tr>
#             <tr>
#                         <th id="T_85be6ebe_b429_11ec_b03c_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col0" class="data row2 col0" >0.151613</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col1" class="data row2 col1" >0.145161</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col2" class="data row2 col2" >0.129032</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col3" class="data row2 col3" >0.122581</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col4" class="data row2 col4" >0.150000</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col5" class="data row2 col5" >0.151613</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row2_col6" class="data row2 col6" >0.150000</td>
#             </tr>
#             <tr>
#                         <th id="T_85be6ebe_b429_11ec_b03c_5c879c826b52level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col0" class="data row3 col0" >0.140011</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col1" class="data row3 col1" >0.138904</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col2" class="data row3 col2" >0.137797</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col3" class="data row3 col3" >0.138904</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col4" class="data row3 col4" >0.144992</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col5" class="data row3 col5" >0.149972</td>
#                         <td id="T_85be6ebe_b429_11ec_b03c_5c879c826b52row3_col6" class="data row3 col6" >0.149419</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## TargetAssociationContinuous Evaluator

# %%
from mofr.basic_evaluators.TargetAssociationContinuous import TargetAssociationContinuousEvaluator

tacoe=TargetAssociationContinuousEvaluator()
#help(tacoe)

# %%
tacoe.d(df).t([('target', 'target_obs')]).pc('p_churn').tc('month')

# %%
tacoe.get_graph()

# %%
tacoe.get_table()
tacoe.table
# Out:
# <style  type="text/css" >
# </style><table id="T_8668af94_b429_11ec_b500_5c879c826b52" style='display:inline'><caption>Different aggregations of target variable "target" vs. the predictor "p_churn" values</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>count</th>        <th class="col_heading level0 col4" colspan=4>sum</th>        <th class="col_heading level0 col8" colspan=4>mean</th>        <th class="col_heading level0 col12" colspan=4>logodds_</th>    </tr>    <tr>        <th class="index_name level1" >month</th>        <th class="col_heading level1 col0" >202001</th>        <th class="col_heading level1 col1" >202002</th>        <th class="col_heading level1 col2" >202003</th>        <th class="col_heading level1 col3" >All</th>        <th class="col_heading level1 col4" >202001</th>        <th class="col_heading level1 col5" >202002</th>        <th class="col_heading level1 col6" >202003</th>        <th class="col_heading level1 col7" >All</th>        <th class="col_heading level1 col8" >202001</th>        <th class="col_heading level1 col9" >202002</th>        <th class="col_heading level1 col10" >202003</th>        <th class="col_heading level1 col11" >All</th>        <th class="col_heading level1 col12" >202001</th>        <th class="col_heading level1 col13" >202002</th>        <th class="col_heading level1 col14" >202003</th>        <th class="col_heading level1 col15" >All</th>    </tr>    <tr>        <th class="index_name level0" >p_churn_binned</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8668af94_b429_11ec_b500_5c879c826b52level0_row0" class="row_heading level0 row0" >(-0.000843, 0.2]</th>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col0" class="data row0 col0" >1927</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col1" class="data row0 col1" >1824</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col2" class="data row0 col2" >1959</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col3" class="data row0 col3" >5710</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col4" class="data row0 col4" >189</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col5" class="data row0 col5" >169</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col6" class="data row0 col6" >189</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col7" class="data row0 col7" >547</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col8" class="data row0 col8" >0.098080</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col9" class="data row0 col9" >0.092654</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col10" class="data row0 col10" >0.096478</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col11" class="data row0 col11" >0.095797</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col12" class="data row0 col12" >-2.218743</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col13" class="data row0 col13" >-2.281658</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col14" class="data row0 col14" >-2.236988</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row0_col15" class="data row0 col15" >-2.244824</td>
#             </tr>
#             <tr>
#                         <th id="T_8668af94_b429_11ec_b500_5c879c826b52level0_row1" class="row_heading level0 row1" >(0.2, 0.4]</th>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col0" class="data row1 col0" >445</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col1" class="data row1 col1" >509</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col2" class="data row1 col2" >486</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col3" class="data row1 col3" >1440</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col4" class="data row1 col4" >265</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col5" class="data row1 col5" >291</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col6" class="data row1 col6" >287</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col7" class="data row1 col7" >843</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col8" class="data row1 col8" >0.595506</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col9" class="data row1 col9" >0.571709</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col10" class="data row1 col10" >0.590535</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col11" class="data row1 col11" >0.585417</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col12" class="data row1 col12" >0.386773</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col13" class="data row1 col13" >0.288828</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col14" class="data row1 col14" >0.366177</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row1_col15" class="data row1 col15" >0.345050</td>
#             </tr>
#             <tr>
#                         <th id="T_8668af94_b429_11ec_b500_5c879c826b52level0_row2" class="row_heading level0 row2" >(0.4, 0.6]</th>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col0" class="data row2 col0" >82</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col1" class="data row2 col1" >72</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col2" class="data row2 col2" >82</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col3" class="data row2 col3" >236</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col4" class="data row2 col4" >38</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col6" class="data row2 col6" >33</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col7" class="data row2 col7" >104</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col8" class="data row2 col8" >0.463415</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col9" class="data row2 col9" >0.458333</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col10" class="data row2 col10" >0.402439</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col11" class="data row2 col11" >0.440678</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col12" class="data row2 col12" >-0.146603</td>
#                         <td id="T_8668af94_b429_11ec_b500_5c879c826b52row2_col13" class="data row2 col13" >-0.167054</td>
#                         <

# %% [markdown]
# # Complex Evaluators

# %% [markdown]
# ## Categorical Predictor Evaluator

# %%
from mofr.complex_evaluators.CategoricalPredictor import CategoricalPredictorEvaluator

capre=CategoricalPredictorEvaluator()
#help(capre)

# %%
capre.d(df).t([('target', 'target_obs')]).pc('categorical_predictor').tc('month')

# %%
capre.get_graph()

# %%
capre.get_table()
# Out:
# <style  type="text/css" >
# </style><table id="T_877e5e36_b429_11ec_b593_5c879c826b52" style='display:inline'><caption>Distribution of predictor "categorical_predictor"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >categorical_predictor %</th>        <th class="col_heading level0 col1" >categorical_predictor</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row0" class="row_heading level0 row0" >A</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row0_col0" class="data row0 col0" >0.150390</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row0_col1" class="data row0 col1" >1195</td>
#             </tr>
#             <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row1" class="row_heading level0 row1" >C</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row1_col0" class="data row1 col0" >0.145608</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row1_col1" class="data row1 col1" >1157</td>
#             </tr>
#             <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row2" class="row_heading level0 row2" >H</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row2_col0" class="data row2 col0" >0.144601</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row2_col1" class="data row2 col1" >1149</td>
#             </tr>
#             <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row3" class="row_heading level0 row3" >F</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row3_col0" class="data row3 col0" >0.143217</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row3_col1" class="data row3 col1" >1138</td>
#             </tr>
#             <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row4" class="row_heading level0 row4" >G</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row4_col0" class="data row4 col0" >0.142839</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row4_col1" class="data row4 col1" >1135</td>
#             </tr>
#             <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row5" class="row_heading level0 row5" >B</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row5_col0" class="data row5 col0" >0.136798</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row5_col1" class="data row5 col1" >1087</td>
#             </tr>
#             <tr>
#                         <th id="T_877e5e36_b429_11ec_b593_5c879c826b52level0_row6" class="row_heading level0 row6" >D</th>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row6_col0" class="data row6 col0" >0.136547</td>
#                         <td id="T_877e5e36_b429_11ec_b593_5c879c826b52row6_col1" class="data row6 col1" >1085</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52" style='display:inline'><caption>Distribution of predictor "categorical_predictor" in time</caption><thead>    <tr>        <th class="index_name level0" >categorical_predictor</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >F</th>        <th class="col_heading level0 col5" >G</th>        <th class="col_heading level0 col6" >H</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col0" class="data row0 col0" >0.143452</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col1" class="data row0 col1" >0.131718</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col2" class="data row0 col2" >0.144587</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col3" class="data row0 col3" >0.147994</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col4" class="data row0 col4" >0.146480</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col5" class="data row0 col5" >0.141938</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row0_col6" class="data row0 col6" >0.143830</td>
#             </tr>
#             <tr>
#                         <th id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col0" class="data row1 col0" >0.152333</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col1" class="data row1 col1" >0.140764</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col2" class="data row1 col2" >0.144620</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col3" class="data row1 col3" >0.136136</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col4" class="data row1 col4" >0.136521</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col5" class="data row1 col5" >0.139607</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row1_col6" class="data row1 col6" >0.150019</td>
#             </tr>
#             <tr>
#                         <th id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col0" class="data row2 col0" >0.155293</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col1" class="data row2 col1" >0.137956</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col2" class="data row2 col2" >0.147547</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col3" class="data row2 col3" >0.125784</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col4" class="data row2 col4" >0.146440</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col5" class="data row2 col5" >0.146809</td>
#                         <td id="T_8781e0a8_b429_11ec_8a7d_5c879c826b52row2_col6" class="data row2 col6" >0.140170</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_878ba33a_b429_11ec_b0ae_5c879c826b52" style='display:inline'><caption>Target association (default rate) of predictor "categorical_predictor" in time</caption><thead>    <tr>        <th class="index_name level0" >categorical_predictor</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >F</th>        <th class="col_heading level0 col5" >G</th>        <th class="col_heading level0 col6" >H</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_878ba33a_b429_11ec_b0ae_5c879c826b52level0_row0" class="row_heading level0 row0" >202001</th>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col0" class="data row0 col0" >0.119730</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col1" class="data row0 col1" >0.129848</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col2" class="data row0 col2" >0.134907</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col3" class="data row0 col3" >0.146712</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col4" class="data row0 col4" >0.155143</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col5" class="data row0 col5" >0.155143</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row0_col6" class="data row0 col6" >0.158516</td>
#             </tr>
#             <tr>
#                         <th id="T_878ba33a_b429_11ec_b0ae_5c879c826b52level0_row1" class="row_heading level0 row1" >202002</th>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col0" class="data row1 col0" >0.148148</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col1" class="data row1 col1" >0.141414</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col2" class="data row1 col2" >0.149832</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col3" class="data row1 col3" >0.148148</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col4" class="data row1 col4" >0.129630</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col5" class="data row1 col5" >0.143098</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row1_col6" class="data row1 col6" >0.139731</td>
#             </tr>
#             <tr>
#                         <th id="T_878ba33a_b429_11ec_b0ae_5c879c826b52level0_row2" class="row_heading level0 row2" >202003</th>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col0" class="data row2 col0" >0.151613</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col1" class="data row2 col1" >0.145161</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col2" class="data row2 col2" >0.129032</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col3" class="data row2 col3" >0.122581</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col4" class="data row2 col4" >0.150000</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col5" class="data row2 col5" >0.151613</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row2_col6" class="data row2 col6" >0.150000</td>
#             </tr>
#             <tr>
#                         <th id="T_878ba33a_b429_11ec_b0ae_5c879c826b52level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col0" class="data row3 col0" >0.140011</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col1" class="data row3 col1" >0.138904</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col2" class="data row3 col2" >0.137797</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col3" class="data row3 col3" >0.138904</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col4" class="data row3 col4" >0.144992</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col5" class="data row3 col5" >0.149972</td>
#                         <td id="T_878ba33a_b429_11ec_b0ae_5c879c826b52row3_col6" class="data row3 col6" >0.149419</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Misc

# %%
# setup plot details
plt.figure(figsize=(7, 8))

#set up data details
df_=df
df_['categorical_predictor']=df_['categorical_predictor'].apply(str)
df_['one']=1
categories=list(df_['categorical_predictor'].unique())
n_categories=len(categories)
#assert the correct number of categories
assert n_categories>=2,  f'The predictor column specified has less than 2 unique categories!'
assert n_categories<=20, f'The predictor column specified has more than {max_categories_} unique categories.'
#  produce table of distribution/share of each category in time
table=df_['categorical_predictor'].value_counts(dropna=False, normalize=True)
#set plotting parameters
plt.bar(table.index,table.values)
plt.xlabel('Categories')
plt.ylabel('Share of the given category')
plt.title(f'Distribution of predictor "categorical_predictor"')
plt.grid()
plt.show()

# %%
# Skipping a lot of other complexity her
f, ax = plt.subplots(figsize=fig_size)
ax.plot(x,y, ...)
# further stuff
return ax

ax.plot(x2, y2, ...)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-f8e34481368d> in <module>
#       1 # Skipping a lot of other complexity her
# ----> 2 f, ax = plt.subplots(figsize=fig_size)
#       3 ax.plot(x,y, ...)
#       4 # further stuff
#       5 return ax
#
# NameError: name 'fig_size' is not defined

# %%
# setup plot details
f, ax = plt.subplots(figsize=(7,8))

#set up data details
df_=df
df_['categorical_predictor']=df_['categorical_predictor'].apply(str)
df_['one']=1
categories=list(df_['categorical_predictor'].unique())
n_categories=len(categories)
#assert the correct number of categories
assert n_categories>=2,  f'The predictor column specified has less than 2 unique categories!'
assert n_categories<=20, f'The predictor column specified has more than {max_categories_} unique categories.'
#  produce table of distribution/share of each category in time
table=df_['categorical_predictor'].value_counts(dropna=False, normalize=True)
#set plotting parameters
plt.bar(table.index,table.values, axes=ax)
plt.xlabel('Categories', axes=ax)
plt.ylabel('Share of the given category', axes=ax)
plt.title(f'Distribution of predictor "categorical_predictor"', axes=ax)
ax.grid()
plt.show()

# %%
def plot_figures(figures, nrows = 1, ncols=1):
    """Plot a dictionary of figures.

    Parameters
    ----------
    figures : <title, figure> dictionary
    ncols : number of columns of subplots wanted in the display
    nrows : number of rows of subplots wanted in the figure
    """

    fig, axeslist = plt.subplots(ncols=ncols, nrows=nrows)
    for ind,title in enumerate(figures):
        axeslist.ravel()[ind].imshow(figures[title], cmap=plt.gray())
        axeslist.ravel()[ind].set_title(title)
        axeslist.ravel()[ind].set_axis_off()
    plt.tight_layout() # optional

# %%
type(sitcae.graph)

# %%
hcae.graph

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(7,8))
fig.suptitle('Categorical Predictor Evaluation')  

[ax1, ax2] = [hcae.graph, sitcae.axis]

plt.show()

# %%
figures = [hcae.axis, sitcae.axis]
f, axarr = plt.subplots(1, len(figures))
for i, figure in enumerate(figures):
    axarr[i]=figure

plt.suptitle("Your title!")
plt.show()

# %%
figures = {'im1': hcae.axis, 'im2': sitcae.axis}

# plot of the images in a figure, with 2 rows and 3 columns
plot_figures(figures, 1, 2)

# %%
xs = np.linspace(0,100,100)
fig, axs = plt.subplots(nrows=1, ncols=2)
axs[0].plot(xs, xs * xs)
axs[1].plot(xs, np.sqrt(xs))

# %%
from matplotlib import pyplot as plt

hcae.get_graph()

sitcae.get_graph()

# %%
pd.cut(df['target'], bins=5)

# %%
df['p_churn_binned']=pd.cut(df['p_churn'], bins=5)

# %%
def logodds_(x):
    mean_=np.mean(x)
    if mean_==1.0:
        return -10.0
    if mean_==0.0:
        return 10.0
    else:
        a=np.log(mean_/(1-mean_))
        return a
    

pd.crosstab(index=df['p_churn_binned'], columns=df['month'], values=df['target'], rownames=None, colnames=None, aggfunc=['count','sum','mean',logodds_], margins=True, margins_name='All', dropna=True, normalize=False)

# %%
a[a.columns[0]].index

# %%
df['categorical_predictor']=df['target_obs'].apply(lambda x: random.choice(['A','B','C', 'D', 'F', 'G', 'H']))

# %%
pd.crosstab(index=df['categorical_predictor'], columns=df['month'], values=df['target'], rownames=None, colnames=None, aggfunc=sum, margins=True, margins_name='All', dropna=True, normalize='columns').transpose()

# %%
df['categorical_predictor'].value_counts(dropna=False, normalize=True).plot.bar(color=['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

# %%
a=df['categorical_predictor'].value_counts(dropna=False, normalize=True)
a

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 8))

# the histogram of the data
n, bins, patches = plt.hist(df['p_churn'], bins='doane', density=False, facecolor='b', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
a.values

# %%
list(df[self.predictor_column].unique())

# %%
l, = plt.plot(a['A'])


#set plotting parameters
fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.ticklabel_format(useOffset=False)
plt.xticks(range(min(a.index), max(a.index)+1))
#plt.xlim(min(_x)-0.1,max(_x)+0.1)
#plt.ylim(-0.01,1.03)
plt.xlabel('Month')
plt.ylabel('GINI')


plt.show()

# %%
a['A']
